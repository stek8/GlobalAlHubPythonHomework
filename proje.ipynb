# %%
print("student management system")

first_name="Seyma"
last_name="Tek"
i=0

while i<3:
    name=input("please enter name:")
    lastname=input("please enter lastname:")
    if first_name==name and last_name==lastname:
        print("Welcome")
        break
    else: 
        print("Try Again")
    i= i+1
    if i==3:
        print("Please Try Again Later")
    

courses_list=("math","science","art","reading","writing","literature","gym")
print("select a course from the below course list if you are done type exit")
print(courses_list)   
num=0
courselist=[]
while True:
    a=input("your courses:")
    courselist.append(a)
    num=num+1
    if a=="exit":
        if num<4 or num>6:
            print("You failed in class")
            break
        else:
            courselist.remove("exit")
            print(courselist)
            break
    else:
        print(courselist)

coursename=input("enter a course name for exam:()")        
print("Write grades for {}".format(coursename))

midterm=int(input("Midterm: "))
if 0< midterm<=100:
    print("midterm grade is {}" .format(midterm)) 
else:
    print("Your number must be between 1-100!")

final=int(input("Final: "))
if 0< final<= 100:
    print("final grade is {}".format(final))
else:
    print("Your number must be between 1-100!")

proje=int(input("Proje: "))
if 0< proje<= 100:
    print("proje grade is {}".format(proje))    
else:
    print("Your number must be between 1-100!")

grade= int (midterm*0.3 + final*0.5 + proje*0.2)
print("Your grade:{}".format(grade))

if grade >= 90:
    print("Your grade AA - passed")
elif 70 <= grade < 90:
    print("Your grade BB - passed")
elif 50 <= grade < 70:
    print("Your grade CC - passed")
elif 30 <= grade < 50:
    print("Your grade DD - passed")
elif grade < 30:
    print("Your grade FF - failure")
# Out:
# student management system
# please enter name:Seyma
# please enter lastname:Tek
# Welcome
# select a course from the below course list if you are done type exit
# ('math', 'science', 'art', 'reading', 'writing', 'literature', 'gym')
# your courses:math
# ['math']
# your courses:art
# ['math', 'art']
# your courses:gym
# ['math', 'art', 'gym']
# your courses:exit
# ['math', 'art', 'gym']
# enter a course name for exam:()gym
# Write grades for gym
# Midterm: 50
# midterm grade is 50
# Final: 50
# final grade is 50
# Proje: 60
# proje grade is 60
# Your grade:52
# Your grade CC - passed
